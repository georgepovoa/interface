# %%
import os
import shutil
import pandas as pd
from rich import inspect
import re

# %%
source_folder = r"C:\Users\nazir\Google Drive\Startaup\Interface Grafica\\"
destination_folder = os.getcwd() + '\\'

# fetch all files
for file_name in os.listdir(source_folder):
    # construct full file path
    source = source_folder + file_name
    destination = destination_folder + file_name
    # copy only files
    if os.path.isfile(source):
        if os.path.exists (destination):
            print ('não copiou pq já existe', file_name)
        else:
            shutil.copy(source, destination)
            print('copiado', file_name)
# Out:
# não copiou pq já existe CFcsvart.csv
# não copiou pq já existe CFcsvcapitulo.csv
# não copiou pq já existe CFcsvdescquestao.csv
# não copiou pq já existe CFcsvniv2.csv
# não copiou pq já existe CFcsvniv3.csv
# não copiou pq já existe CFcsvniv4.csv
# não copiou pq já existe CFcsvquestao.csv
# não copiou pq já existe CFcsvsec.csv
# não copiou pq já existe CFcsvsubsec.csv
# não copiou pq já existe CFcsvtitulo.csv
# não copiou pq já existe CFcsvtudo.csv
# não copiou pq já existe CFcsvtudolei.csv
# não copiou pq já existe CFcsvtudoquestao.csv
# não copiou pq já existe modelo_sg_sem_lema.txt
# não copiou pq já existe questao_falta_catalogar_similaridade.csv
# não copiou pq já existe q_falta_catalogar.csv
# não copiou pq já existe q_falta_catalogar_tratada.csv
# não copiou pq já existe treino.csv

# %%
df_questoes_similaridade = pd.read_csv ('questao_falta_catalogar_similaridade.csv')
df_questoes_similaridade
# Out:
#       Unnamed: 0                                 questão pesquisada  \
# 0              0   O regime próprio de previdência social dos se...
# 1              1   O princípio da intranscendência subjetiva con...
# 2              2   Atos de improbidade administrativa importarão...
# 3              3   As condutas do Estado devem pautar-se pela sa...
# 4              4   A Constituição Federal de 1988 contemplou a n...
# ...          ...                                                ...
# 1263        1263    A criação de associações independe de autori...
# 1264        1264    A liberdade de exercício profissional é ilim...
# 1265        1265    Constituem objetivos fundamentais da Repúbli...
# 1266        1266       Estrangeiros não podem ser agentes públicos.
# 1267        1267    A segurança viária compreende a educação, a ...
#
#                                              resultado1  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 2º São Poderes da União, independentes e ...
# 2     § 4º - Os atos de improbidade administrativa i...
# 3     § 1º São princípios institucionais do Ministér...
# 4     Art. 12. São brasileiros:§ 4º - Será declarada...
# ...                                                 ...
# 1263  § 7º Fundado nos princípios da dignidade da pe...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 1º A República Federativa do Brasil, form...
# 1266  § 6º As pessoas jurídicas de direito público e...
# 1267  Art. 144. A segurança pública, dever do Estado...
#
#                      endereço1  \
# 0           cf88,2,11,3,,41,,,
# 1               cf88,0,,,,1,,,
# 2        cf88,2,11,2,,37,393,,
# 3      cf88,3,15,28,,131,892,,
# 4       cf88,1,2,,,11,154,39,0
# ...                        ...
# 1263    cf88,7,31,,,247,1471,,
# 1264         cf88,1,0,,,4,33,,
# 1265           cf88,0,,,,0,3,,
# 1266     cf88,2,11,2,,37,395,,
# 1267  cf88,4,18,,,149,981,321,
#
#                                              resultado2  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 9º  Lei complementar estabelecerá outros cas...
# 2     § 4º - Os atos de improbidade administrativa i...
# 3     Parágrafo único. A aplicação dos recursos prov...
# 4     Art. 12. São brasileiros:§ 4º - Será declarada...
# ...                                                 ...
# 1263  Art. 21. Compete à União:XI - explorar, direta...
# 1264  Art. 8º É livre a associação profissional ou s...
# 1265  Art. 3º Constituem objetivos fundamentais da R...
# 1266  Art. 151. É vedado à União:II - tributar a ren...
# 1267  Art. 5º Todos são iguais perante a lei, sem di...
#
#                      endereço2  \
# 0     cf88,2,11,3,,41,420,114,
# 1          cf88,1,3,,,13,168,,
# 2        cf88,2,11,2,,37,393,,
# 3      cf88,5,19,35,,154,993,,
# 4       cf88,1,2,,,11,154,39,1
# ...                        ...
# 1263       cf88,2,6,,,20,215,,
# 1264        cf88,1,1,,,7,144,,
# 1265           cf88,0,,,,2,6,,
# 1266  cf88,5,19,36,,158,1016,,
# 1267         cf88,1,0,,,4,89,,
#
#                                              resultado3  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 2º São Poderes da União, independentes e ...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Parágrafo único. É assegurado a todos o livre ...
# 4     Art. 12. São brasileiros:§ 4º - Será declarada...
# ...                                                 ...
# 1263  Art. 5º Todos são iguais perante a lei, sem di...
# 1264  Art. 8º É livre a associação profissional ou s...
# 1265  Art. 3º Constituem objetivos fundamentais da R...
# 1266  § 4º Os gestores locais do sistema único de sa...
# 1267  Art. 5º Todos são iguais perante a lei, sem di...
#
#                      endereço3  \
# 0     cf88,2,11,3,,41,420,115,
# 1               cf88,0,,,,1,,,
# 2          cf88,1,3,,,14,175,,
# 3       cf88,6,21,,,187,1189,,
# 4        cf88,1,2,,,11,154,38,
# ...                        ...
# 1263         cf88,1,0,,,4,38,,
# 1264        cf88,1,1,,,7,142,,
# 1265           cf88,0,,,,2,8,,
# 1266  cf88,7,26,44,,215,1284,,
# 1267         cf88,1,0,,,4,93,,
#
#                                              resultado4  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 2º São Poderes da União, independentes e ...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 5º Todos são iguais perante a lei, sem di...
# 4     Art. 12. São brasileiros:§ 4º - Será declarada...
# ...                                                 ...
# 1263  § 4º É vedada a criação de Tribunais, Conselho...
# 1264  § 1º As normas definidoras dos direitos e gara...
# 1265  Art. 3º Constituem objetivos fundamentais da R...
# 1266  Art. 241. A União, os Estados, o Distrito Fede...
# 1267  Art. 5º Todos são iguais perante a lei, sem di...
#
#                      endereço4  ...  \
# 0     cf88,2,11,3,,41,444,122,  ...
# 1               cf88,0,,,,1,,,  ...
# 2             cf88,1,3,,,14,,,  ...
# 3            cf88,1,0,,,4,53,,  ...
# 4        cf88,1,2,,,11,154,39,  ...
# ...                        ...  ...
# 1263       cf88,2,8,,,31,341,,  ...
# 1264         cf88,1,0,,,4,99,,  ...
# 1265            cf88,0,,,,2,,,  ...
# 1266          cf88,8,,,,262,,,  ...
# 1267         cf88,1,0,,,4,89,,  ...
#
#                                              resultado6  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 1º São princípios institucionais do Ministér...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     § 3º Em caso de greve em atividade essencial, ...
# 4     Art. 109. Aos juízes federais compete processa...
# ...                                                 ...
# 1263  § 1º São princípios institucionais do Ministér...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 1º A República Federativa do Brasil, form...
# 1266  § 2º A lei não poderá estabelecer distinção en...
# 1267  § 6º As pessoas jurídicas de direito público e...
#
#                      endereço6  \
# 0     cf88,2,11,3,,41,444,120,
# 1      cf88,3,15,28,,131,892,,
# 2          cf88,1,3,,,14,173,,
# 3      cf88,3,14,24,,118,861,,
# 4      cf88,3,14,23,,112,833,,
# ...                        ...
# 1263   cf88,3,15,28,,131,892,,
# 1264         cf88,1,0,,,4,34,,
# 1265           cf88,0,,,,0,3,,
# 1266       cf88,1,2,,,11,152,,
# 1267     cf88,2,11,2,,37,395,,
#
#                                              resultado7  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 4º - Os atos de improbidade administrativa i...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 150. Sem prejuízo de outras garantias ass...
# 4     § 4º - Será declarada a perda da nacionalidade...
# ...                                                 ...
# 1263  § 5º Leis complementares da União e dos Estado...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 3º Constituem objetivos fundamentais da R...
# 1266  Art. 5º Todos são iguais perante a lei, sem di...
# 1267  Art. 144. A segurança pública, dever do Estado...
#
#                         endereço7  \
# 0        cf88,2,11,3,,41,444,117,
# 1           cf88,2,11,2,,37,393,,
# 2             cf88,1,3,,,14,172,,
# 3     cf88,5,19,36,,157,1004,335,
# 4             cf88,1,2,,,11,154,,
# ...                           ...
# 1263      cf88,3,15,28,,132,904,,
# 1264            cf88,1,0,,,4,26,,
# 1265              cf88,0,,,,2,9,,
# 1266            cf88,1,0,,,4,51,,
# 1267     cf88,4,18,,,149,981,322,
#
#                                              resultado8  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 170. A ordem econômica, fundada na valori...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 150. Sem prejuízo de outras garantias ass...
# 4     Art. 128. O Ministério Público abrange:§ 5º Le...
# ...                                                 ...
# 1263  § 2º Cabe aos Estados explorar diretamente, ou...
# 1264  Art. 8º É livre a associação profissional ou s...
# 1265  Art. 1º A República Federativa do Brasil, form...
# 1266  § 6º As pessoas jurídicas de direito público e...
# 1267  Art. 227. É dever da família, da sociedade e d...
#
#                          endereço8  \
# 0         cf88,2,11,3,,41,444,118,
# 1           cf88,6,21,,,187,1182,,
# 2                 cf88,1,3,,,14,,,
# 3      cf88,5,19,36,,157,1004,335,
# 4     cf88,3,15,28,,132,904,291,21
# ...                            ...
# 1263           cf88,2,7,,,24,294,,
# 1264               cf88,1,1,,,7,,,
# 1265               cf88,0,,,,0,4,,
# 1266         cf88,2,11,2,,37,395,,
# 1267     cf88,7,31,,,248,1475,535,
#
#                                              resultado9  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 4º - Os atos de improbidade administrativa i...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 148. A União, mediante lei complementar, ...
# 4     Art. 12. São brasileiros:II - naturalizados:b)...
# ...                                                 ...
# 1263  Art. 8º É livre a associação profissional ou s...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 170. A ordem econômica, fundada na valori...
# 1266  Art. 198. As ações e serviços públicos de saúd...
# 1267  Art. 5º Todos são iguais perante a lei, sem di...
#
#                      endereço9  \
# 0     cf88,2,11,3,,41,420,116,
# 1        cf88,2,11,2,,37,393,,
# 2          cf88,1,3,,,14,171,,
# 3      cf88,5,19,35,,154,992,,
# 4        cf88,1,2,,,11,150,30,
# ...                        ...
# 1263        cf88,1,1,,,7,138,,
# 1264         cf88,1,0,,,4,28,,
# 1265    cf88,6,21,,,187,1186,,
# 1266  cf88,7,26,44,,215,1279,,
# 1267         cf88,1,0,,,4,53,,
#
#                                             resultado10  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 207. As universidades gozam de autonomia ...
# 2     Parágrafo único. Nos casos previstos nos incis...
# 3     Art. 223. Compete ao Poder Executivo outorgar ...
# 4     Art. 151. É vedado à União:III - instituir ise...
# ...                                                 ...
# 1263  § 2º A lei regulará a organização e o funciona...
# 1264  Art. 8º É livre a associação profissional ou s...
# 1265  Art. 4º A República Federativa do Brasil rege-...
# 1266  Art. 5º Todos são iguais perante a lei, sem di...
# 1267  Art. 225. Todos têm direito ao meio ambiente e...
#
#                      endereço10
# 0      cf88,2,11,3,,41,444,123,
# 1          cf88,7,27,47,,224,,,
# 2         cf88,3,12,9,,53,516,,
# 3            cf88,7,29,,,244,,,
# 4      cf88,5,19,36,,158,1017,,
# ...                         ...
# 1263    cf88,3,13,19,3,91,691,,
# 1264         cf88,1,1,,,7,141,,
# 1265           cf88,0,,,,3,11,,
# 1266         cf88,1,0,,,4,54,3,
# 1267  cf88,7,30,,,246,1458,528,
#
# [1268 rows x 22 columns]

# %%
df_questoes_comentario = pd.read_csv ('q_falta_catalogar.csv')

# %%
df_questoes_comentario
# Out:
#       Unnamed: 0  QuestãoN  1  IndQconc  \
# 0              0         0  0   1786102
# 1              1         1  0   1786101
# 2              2         2  0   1786100
# 3              3         3  0   1786099
# 4              4         4  0   1786098
# ...          ...       ... ..       ...
# 1263        1263       733  0    967373
# 1264        1264       734  0    967372
# 1265        1265       735  0    967371
# 1266        1266       736  0    967293
# 1267        1267       737  0    965650
#
#                                                Assuntos   Ano        5  \
# 0     Administração Pública – Disposições Gerais e S...  2021  Quadrix
# 1     Administração Pública – Disposições Gerais e S...  2021  Quadrix
# 2     Administração Pública – Disposições Gerais e S...  2021  Quadrix
# 3     Administração Pública – Disposições Gerais e S...  2021  Quadrix
# 4                             Direitos da Nacionalidade  2021  Quadrix
# ...                                                 ...   ...      ...
# 1263         Direitos Individuais , Direito à Liberdade  2019  Quadrix
# 1264         Direitos Individuais , Direito à Liberdade  2019  Quadrix
# 1265  Princípios Fundamentais da República , Objetiv...  2019  Quadrix
# 1266  Administração Pública – Disposições Gerais e S...  2019  Quadrix
# 1267  Defesa do Estado e das Instituições Democrátic...  2019    CESPE
#
#                   Orgao                             Cargo  \
# 0     CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 1     CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 2     CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 3     CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 4     CREFONO-4ª Região              Fonoaudiólogo Fiscal
# ...                 ...                               ...
# 1263              CRESS                  SC Agente Fiscal
# 1264              CRESS                  SC Agente Fiscal
# 1265              CRESS                  SC Agente Fiscal
# 1266              CRESS  SC Assistente Administrativo Jr.
# 1267                PRF       Policial Rodoviário Federal
#
#                                                 Questão          Tipo  \
# 0     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 1     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 2     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 3     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 4     A expressão “direitos fundamentais” surgiu na ...  Certo/Errado
# ...                                                 ...           ...
# 1263  Em relação à Constituição Federal de 1988 (CF)...  Certo/Errado
# 1264  Em relação à Constituição Federal de 1988 (CF)...  Certo/Errado
# 1265  Em relação à Constituição Federal de 1988 (CF)...  Certo/Errado
# 1266  Quanto aos agentes e serviços públicos, julgue...  Certo/Errado
# 1267  À luz da Constituição Federal de 1988, julgue ...  Certo/Errado
#
#      gabarito                                         Comentario  \
# 0       Certo  Comentários ( 2 )Raphael P.S.T. 19 de Agosto d...
# 1      Errado  Comentários ( 5 )Doraci ✌❤️✍ 19 de Agosto de 2...
# 2       Certo  Comentários ( 3 )Ronnildo Araujo 18 de Agosto ...
# 3       Certo  Comentários ( 2 )Ronnildo Araujo 18 de Agosto ...
# 4      Errado  Comentários ( 5 )Junior Schettine 18 de Agosto...
# ...       ...                                                ...
# 1263    Certo  Comentários ( 22 )Wandinha 10 de Fevereiro de ...
# 1264   Errado  Comentários ( 33 )Daniel Martins 16 de Feverei...
# 1265   Errado  Comentários ( 39 )Thiago Martins Rosa 20 de Ju...
# 1266   Errado  Comentários ( 29 )Maria Quitéria Concurseira. ...
# 1267    Certo  Comentários ( 95 ) Estatísticas Cadernos Criar...
#
#                                                 comando  \
# 0     O artigo 37 da Constituição Federal de 1988 di...
# 1     O artigo 37 da Constituição Federal de 1988 di...
# 2     O artigo 37 da Constituição Federal de 1988 di...
# 3     O artigo 37 da Constituição Federal de 1988 di...
# 4     A expressão “direitos fundamentais” surgiu na ...
# ...                                                 ...
# 1263  Em relação à Constituição Federal de 1988 (CF)...
# 1264  Em relação à Constituição Federal de 1988 (CF)...
# 1265  Em relação à Constituição Federal de 1988 (CF)...
# 1266  Quanto aos agentes e serviços públicos, julgue...
# 1267  À luz da Constituição Federal de 1988, julgue ...
#
#                                              texto item  \
# 0      O regime próprio de previdência social dos se...
# 1      O princípio da intranscendência subjetiva con...
# 2      Atos de improbidade administrativa importarão...
# 3      As condutas do Estado devem pautar-se pela sa...
# 4      A Constituição Federal de 1988 contemplou a n...
# ...                                                 ...
# 1263    A criação de associações independe de autori...
# 1264    A liberdade de exercício profissional é ilim...
# 1265    Constituem objetivos fundamentais da Repúbli...
# 1266       Estrangeiros não podem ser agentes públicos.
# 1267    A segurança viária compreende a educação, a ...
#
#                                        referencia_final
# 0                                ['cf88,2,11,3,,41,,,']
# 1                                 ['cf88,1,0,,,4,65,,']
# 2     ['cf88,2,11,2,,37,393,,', 'cf88,1,3,,,14,,,', ...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1263           ['cf88,1,0,,,4,,,', 'cf88,1,0,,,4,38,,']
# 1264                                                 []
# 1265  ['cf88,0,,,,0,,,', 'cf88,0,,,,1,,,', 'cf88,0,,...
# 1266    ['cf88,2,11,2,,37,368,,', 'cf88,2,11,2,,37,,,']
# 1267                                                 []
#
# [1268 rows x 16 columns]

# %%
df_questoes_final = df_questoes_comentario.drop(['Unnamed: 0','QuestãoN','1','Comentario'],axis= 1)

# %%
df_questoes_final= df_questoes_final.rename(columns={'referencia_final':'referencia_comentario'})

# %%
df_questoes_final
# Out:
#       IndQconc                                           Assuntos   Ano  \
# 0      1786102  Administração Pública – Disposições Gerais e S...  2021
# 1      1786101  Administração Pública – Disposições Gerais e S...  2021
# 2      1786100  Administração Pública – Disposições Gerais e S...  2021
# 3      1786099  Administração Pública – Disposições Gerais e S...  2021
# 4      1786098                          Direitos da Nacionalidade  2021
# ...        ...                                                ...   ...
# 1263    967373         Direitos Individuais , Direito à Liberdade  2019
# 1264    967372         Direitos Individuais , Direito à Liberdade  2019
# 1265    967371  Princípios Fundamentais da República , Objetiv...  2019
# 1266    967293  Administração Pública – Disposições Gerais e S...  2019
# 1267    965650  Defesa do Estado e das Instituições Democrátic...  2019
#
#             5              Orgao                             Cargo  \
# 0     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 1     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 2     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 3     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 4     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# ...       ...                ...                               ...
# 1263  Quadrix              CRESS                  SC Agente Fiscal
# 1264  Quadrix              CRESS                  SC Agente Fiscal
# 1265  Quadrix              CRESS                  SC Agente Fiscal
# 1266  Quadrix              CRESS  SC Assistente Administrativo Jr.
# 1267    CESPE                PRF       Policial Rodoviário Federal
#
#                                                 Questão          Tipo  \
# 0     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 1     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 2     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 3     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 4     A expressão “direitos fundamentais” surgiu na ...  Certo/Errado
# ...                                                 ...           ...
# 1263  Em relação à Constituição Federal de 1988 (CF)...  Certo/Errado
# 1264  Em relação à Constituição Federal de 1988 (CF)...  Certo/Errado
# 1265  Em relação à Constituição Federal de 1988 (CF)...  Certo/Errado
# 1266  Quanto aos agentes e serviços públicos, julgue...  Certo/Errado
# 1267  À luz da Constituição Federal de 1988, julgue ...  Certo/Errado
#
#      gabarito                                            comando  \
# 0       Certo  O artigo 37 da Constituição Federal de 1988 di...
# 1      Errado  O artigo 37 da Constituição Federal de 1988 di...
# 2       Certo  O artigo 37 da Constituição Federal de 1988 di...
# 3       Certo  O artigo 37 da Constituição Federal de 1988 di...
# 4      Errado  A expressão “direitos fundamentais” surgiu na ...
# ...       ...                                                ...
# 1263    Certo  Em relação à Constituição Federal de 1988 (CF)...
# 1264   Errado  Em relação à Constituição Federal de 1988 (CF)...
# 1265   Errado  Em relação à Constituição Federal de 1988 (CF)...
# 1266   Errado  Quanto aos agentes e serviços públicos, julgue...
# 1267    Certo  À luz da Constituição Federal de 1988, julgue ...
#
#                                              texto item  \
# 0      O regime próprio de previdência social dos se...
# 1      O princípio da intranscendência subjetiva con...
# 2      Atos de improbidade administrativa importarão...
# 3      As condutas do Estado devem pautar-se pela sa...
# 4      A Constituição Federal de 1988 contemplou a n...
# ...                                                 ...
# 1263    A criação de associações independe de autori...
# 1264    A liberdade de exercício profissional é ilim...
# 1265    Constituem objetivos fundamentais da Repúbli...
# 1266       Estrangeiros não podem ser agentes públicos.
# 1267    A segurança viária compreende a educação, a ...
#
#                                   referencia_comentario
# 0                                ['cf88,2,11,3,,41,,,']
# 1                                 ['cf88,1,0,,,4,65,,']
# 2     ['cf88,2,11,2,,37,393,,', 'cf88,1,3,,,14,,,', ...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1263           ['cf88,1,0,,,4,,,', 'cf88,1,0,,,4,38,,']
# 1264                                                 []
# 1265  ['cf88,0,,,,0,,,', 'cf88,0,,,,1,,,', 'cf88,0,,...
# 1266    ['cf88,2,11,2,,37,368,,', 'cf88,2,11,2,,37,,,']
# 1267                                                 []
#
# [1268 rows x 12 columns]

# %%
df_questoes_similaridade = df_questoes_similaridade.drop(['Unnamed: 0','questão pesquisada'],axis=1)

# %%
df_questoes_similaridade
# Out:
#                                              resultado1  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 2º São Poderes da União, independentes e ...
# 2     § 4º - Os atos de improbidade administrativa i...
# 3     § 1º São princípios institucionais do Ministér...
# 4     Art. 12. São brasileiros:§ 4º - Será declarada...
# ...                                                 ...
# 1263  § 7º Fundado nos princípios da dignidade da pe...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 1º A República Federativa do Brasil, form...
# 1266  § 6º As pessoas jurídicas de direito público e...
# 1267  Art. 144. A segurança pública, dever do Estado...
#
#                      endereço1  \
# 0           cf88,2,11,3,,41,,,
# 1               cf88,0,,,,1,,,
# 2        cf88,2,11,2,,37,393,,
# 3      cf88,3,15,28,,131,892,,
# 4       cf88,1,2,,,11,154,39,0
# ...                        ...
# 1263    cf88,7,31,,,247,1471,,
# 1264         cf88,1,0,,,4,33,,
# 1265           cf88,0,,,,0,3,,
# 1266     cf88,2,11,2,,37,395,,
# 1267  cf88,4,18,,,149,981,321,
#
#                                              resultado2  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 9º  Lei complementar estabelecerá outros cas...
# 2     § 4º - Os atos de improbidade administrativa i...
# 3     Parágrafo único. A aplicação dos recursos prov...
# 4     Art. 12. São brasileiros:§ 4º - Será declarada...
# ...                                                 ...
# 1263  Art. 21. Compete à União:XI - explorar, direta...
# 1264  Art. 8º É livre a associação profissional ou s...
# 1265  Art. 3º Constituem objetivos fundamentais da R...
# 1266  Art. 151. É vedado à União:II - tributar a ren...
# 1267  Art. 5º Todos são iguais perante a lei, sem di...
#
#                      endereço2  \
# 0     cf88,2,11,3,,41,420,114,
# 1          cf88,1,3,,,13,168,,
# 2        cf88,2,11,2,,37,393,,
# 3      cf88,5,19,35,,154,993,,
# 4       cf88,1,2,,,11,154,39,1
# ...                        ...
# 1263       cf88,2,6,,,20,215,,
# 1264        cf88,1,1,,,7,144,,
# 1265           cf88,0,,,,2,6,,
# 1266  cf88,5,19,36,,158,1016,,
# 1267         cf88,1,0,,,4,89,,
#
#                                              resultado3  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 2º São Poderes da União, independentes e ...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Parágrafo único. É assegurado a todos o livre ...
# 4     Art. 12. São brasileiros:§ 4º - Será declarada...
# ...                                                 ...
# 1263  Art. 5º Todos são iguais perante a lei, sem di...
# 1264  Art. 8º É livre a associação profissional ou s...
# 1265  Art. 3º Constituem objetivos fundamentais da R...
# 1266  § 4º Os gestores locais do sistema único de sa...
# 1267  Art. 5º Todos são iguais perante a lei, sem di...
#
#                      endereço3  \
# 0     cf88,2,11,3,,41,420,115,
# 1               cf88,0,,,,1,,,
# 2          cf88,1,3,,,14,175,,
# 3       cf88,6,21,,,187,1189,,
# 4        cf88,1,2,,,11,154,38,
# ...                        ...
# 1263         cf88,1,0,,,4,38,,
# 1264        cf88,1,1,,,7,142,,
# 1265           cf88,0,,,,2,8,,
# 1266  cf88,7,26,44,,215,1284,,
# 1267         cf88,1,0,,,4,93,,
#
#                                              resultado4  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 2º São Poderes da União, independentes e ...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 5º Todos são iguais perante a lei, sem di...
# 4     Art. 12. São brasileiros:§ 4º - Será declarada...
# ...                                                 ...
# 1263  § 4º É vedada a criação de Tribunais, Conselho...
# 1264  § 1º As normas definidoras dos direitos e gara...
# 1265  Art. 3º Constituem objetivos fundamentais da R...
# 1266  Art. 241. A União, os Estados, o Distrito Fede...
# 1267  Art. 5º Todos são iguais perante a lei, sem di...
#
#                      endereço4  \
# 0     cf88,2,11,3,,41,444,122,
# 1               cf88,0,,,,1,,,
# 2             cf88,1,3,,,14,,,
# 3            cf88,1,0,,,4,53,,
# 4        cf88,1,2,,,11,154,39,
# ...                        ...
# 1263       cf88,2,8,,,31,341,,
# 1264         cf88,1,0,,,4,99,,
# 1265            cf88,0,,,,2,,,
# 1266          cf88,8,,,,262,,,
# 1267         cf88,1,0,,,4,89,,
#
#                                              resultado5  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 92. São órgãos do Poder Judiciário:I- o C...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     § 3º Em caso de greve em atividade essencial, ...
# 4     Art. 15. É vedada a cassação de direitos polít...
# ...                                                 ...
# 1263  § 1º É assegurada aos partidos políticos auton...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 3º Constituem objetivos fundamentais da R...
# 1266  Art. 5º Todos são iguais perante a lei, sem di...
# 1267  Art. 144. A segurança pública, dever do Estado...
#
#                      endereço5  \
# 0     cf88,2,11,3,,41,444,125,
# 1       cf88,3,14,20,,93,703,,
# 2          cf88,1,3,,,14,174,,
# 3      cf88,3,14,24,,118,861,,
# 4          cf88,1,3,,,14,171,,
# ...                        ...
# 1263       cf88,1,4,,,16,180,,
# 1264         cf88,1,0,,,4,37,,
# 1265           cf88,0,,,,2,7,,
# 1266        cf88,1,0,,,4,54,2,
# 1267  cf88,4,18,,,149,972,318,
#
#                                              resultado6  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 1º São princípios institucionais do Ministér...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     § 3º Em caso de greve em atividade essencial, ...
# 4     Art. 109. Aos juízes federais compete processa...
# ...                                                 ...
# 1263  § 1º São princípios institucionais do Ministér...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 1º A República Federativa do Brasil, form...
# 1266  § 2º A lei não poderá estabelecer distinção en...
# 1267  § 6º As pessoas jurídicas de direito público e...
#
#                      endereço6  \
# 0     cf88,2,11,3,,41,444,120,
# 1      cf88,3,15,28,,131,892,,
# 2          cf88,1,3,,,14,173,,
# 3      cf88,3,14,24,,118,861,,
# 4      cf88,3,14,23,,112,833,,
# ...                        ...
# 1263   cf88,3,15,28,,131,892,,
# 1264         cf88,1,0,,,4,34,,
# 1265           cf88,0,,,,0,3,,
# 1266       cf88,1,2,,,11,152,,
# 1267     cf88,2,11,2,,37,395,,
#
#                                              resultado7  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 4º - Os atos de improbidade administrativa i...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 150. Sem prejuízo de outras garantias ass...
# 4     § 4º - Será declarada a perda da nacionalidade...
# ...                                                 ...
# 1263  § 5º Leis complementares da União e dos Estado...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 3º Constituem objetivos fundamentais da R...
# 1266  Art. 5º Todos são iguais perante a lei, sem di...
# 1267  Art. 144. A segurança pública, dever do Estado...
#
#                         endereço7  \
# 0        cf88,2,11,3,,41,444,117,
# 1           cf88,2,11,2,,37,393,,
# 2             cf88,1,3,,,14,172,,
# 3     cf88,5,19,36,,157,1004,335,
# 4             cf88,1,2,,,11,154,,
# ...                           ...
# 1263      cf88,3,15,28,,132,904,,
# 1264            cf88,1,0,,,4,26,,
# 1265              cf88,0,,,,2,9,,
# 1266            cf88,1,0,,,4,51,,
# 1267     cf88,4,18,,,149,981,322,
#
#                                              resultado8  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 170. A ordem econômica, fundada na valori...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 150. Sem prejuízo de outras garantias ass...
# 4     Art. 128. O Ministério Público abrange:§ 5º Le...
# ...                                                 ...
# 1263  § 2º Cabe aos Estados explorar diretamente, ou...
# 1264  Art. 8º É livre a associação profissional ou s...
# 1265  Art. 1º A República Federativa do Brasil, form...
# 1266  § 6º As pessoas jurídicas de direito público e...
# 1267  Art. 227. É dever da família, da sociedade e d...
#
#                          endereço8  \
# 0         cf88,2,11,3,,41,444,118,
# 1           cf88,6,21,,,187,1182,,
# 2                 cf88,1,3,,,14,,,
# 3      cf88,5,19,36,,157,1004,335,
# 4     cf88,3,15,28,,132,904,291,21
# ...                            ...
# 1263           cf88,2,7,,,24,294,,
# 1264               cf88,1,1,,,7,,,
# 1265               cf88,0,,,,0,4,,
# 1266         cf88,2,11,2,,37,395,,
# 1267     cf88,7,31,,,248,1475,535,
#
#                                              resultado9  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 4º - Os atos de improbidade administrativa i...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 148. A União, mediante lei complementar, ...
# 4     Art. 12. São brasileiros:II - naturalizados:b)...
# ...                                                 ...
# 1263  Art. 8º É livre a associação profissional ou s...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 170. A ordem econômica, fundada na valori...
# 1266  Art. 198. As ações e serviços públicos de saúd...
# 1267  Art. 5º Todos são iguais perante a lei, sem di...
#
#                      endereço9  \
# 0     cf88,2,11,3,,41,420,116,
# 1        cf88,2,11,2,,37,393,,
# 2          cf88,1,3,,,14,171,,
# 3      cf88,5,19,35,,154,992,,
# 4        cf88,1,2,,,11,150,30,
# ...                        ...
# 1263        cf88,1,1,,,7,138,,
# 1264         cf88,1,0,,,4,28,,
# 1265    cf88,6,21,,,187,1186,,
# 1266  cf88,7,26,44,,215,1279,,
# 1267         cf88,1,0,,,4,53,,
#
#                                             resultado10  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 207. As universidades gozam de autonomia ...
# 2     Parágrafo único. Nos casos previstos nos incis...
# 3     Art. 223. Compete ao Poder Executivo outorgar ...
# 4     Art. 151. É vedado à União:III - instituir ise...
# ...                                                 ...
# 1263  § 2º A lei regulará a organização e o funciona...
# 1264  Art. 8º É livre a associação profissional ou s...
# 1265  Art. 4º A República Federativa do Brasil rege-...
# 1266  Art. 5º Todos são iguais perante a lei, sem di...
# 1267  Art. 225. Todos têm direito ao meio ambiente e...
#
#                      endereço10
# 0      cf88,2,11,3,,41,444,123,
# 1          cf88,7,27,47,,224,,,
# 2         cf88,3,12,9,,53,516,,
# 3            cf88,7,29,,,244,,,
# 4      cf88,5,19,36,,158,1017,,
# ...                         ...
# 1263    cf88,3,13,19,3,91,691,,
# 1264         cf88,1,1,,,7,141,,
# 1265           cf88,0,,,,3,11,,
# 1266         cf88,1,0,,,4,54,3,
# 1267  cf88,7,30,,,246,1458,528,
#
# [1268 rows x 20 columns]

# %%
df_questoes_final = df_questoes_final.join(df_questoes_similaridade)

# %%
df_questoes_final
# Out:
#       IndQconc                                           Assuntos   Ano  \
# 0      1786102  Administração Pública – Disposições Gerais e S...  2021
# 1      1786101  Administração Pública – Disposições Gerais e S...  2021
# 2      1786100  Administração Pública – Disposições Gerais e S...  2021
# 3      1786099  Administração Pública – Disposições Gerais e S...  2021
# 4      1786098                          Direitos da Nacionalidade  2021
# ...        ...                                                ...   ...
# 1263    967373         Direitos Individuais , Direito à Liberdade  2019
# 1264    967372         Direitos Individuais , Direito à Liberdade  2019
# 1265    967371  Princípios Fundamentais da República , Objetiv...  2019
# 1266    967293  Administração Pública – Disposições Gerais e S...  2019
# 1267    965650  Defesa do Estado e das Instituições Democrátic...  2019
#
#             5              Orgao                             Cargo  \
# 0     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 1     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 2     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 3     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 4     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# ...       ...                ...                               ...
# 1263  Quadrix              CRESS                  SC Agente Fiscal
# 1264  Quadrix              CRESS                  SC Agente Fiscal
# 1265  Quadrix              CRESS                  SC Agente Fiscal
# 1266  Quadrix              CRESS  SC Assistente Administrativo Jr.
# 1267    CESPE                PRF       Policial Rodoviário Federal
#
#                                                 Questão          Tipo  \
# 0     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 1     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 2     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 3     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 4     A expressão “direitos fundamentais” surgiu na ...  Certo/Errado
# ...                                                 ...           ...
# 1263  Em relação à Constituição Federal de 1988 (CF)...  Certo/Errado
# 1264  Em relação à Constituição Federal de 1988 (CF)...  Certo/Errado
# 1265  Em relação à Constituição Federal de 1988 (CF)...  Certo/Errado
# 1266  Quanto aos agentes e serviços públicos, julgue...  Certo/Errado
# 1267  À luz da Constituição Federal de 1988, julgue ...  Certo/Errado
#
#      gabarito                                            comando  ...  \
# 0       Certo  O artigo 37 da Constituição Federal de 1988 di...  ...
# 1      Errado  O artigo 37 da Constituição Federal de 1988 di...  ...
# 2       Certo  O artigo 37 da Constituição Federal de 1988 di...  ...
# 3       Certo  O artigo 37 da Constituição Federal de 1988 di...  ...
# 4      Errado  A expressão “direitos fundamentais” surgiu na ...  ...
# ...       ...                                                ...  ...
# 1263    Certo  Em relação à Constituição Federal de 1988 (CF)...  ...
# 1264   Errado  Em relação à Constituição Federal de 1988 (CF)...  ...
# 1265   Errado  Em relação à Constituição Federal de 1988 (CF)...  ...
# 1266   Errado  Quanto aos agentes e serviços públicos, julgue...  ...
# 1267    Certo  À luz da Constituição Federal de 1988, julgue ...  ...
#
#                                              resultado6  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 1º São princípios institucionais do Ministér...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     § 3º Em caso de greve em atividade essencial, ...
# 4     Art. 109. Aos juízes federais compete processa...
# ...                                                 ...
# 1263  § 1º São princípios institucionais do Ministér...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 1º A República Federativa do Brasil, form...
# 1266  § 2º A lei não poderá estabelecer distinção en...
# 1267  § 6º As pessoas jurídicas de direito público e...
#
#                      endereço6  \
# 0     cf88,2,11,3,,41,444,120,
# 1      cf88,3,15,28,,131,892,,
# 2          cf88,1,3,,,14,173,,
# 3      cf88,3,14,24,,118,861,,
# 4      cf88,3,14,23,,112,833,,
# ...                        ...
# 1263   cf88,3,15,28,,131,892,,
# 1264         cf88,1,0,,,4,34,,
# 1265           cf88,0,,,,0,3,,
# 1266       cf88,1,2,,,11,152,,
# 1267     cf88,2,11,2,,37,395,,
#
#                                              resultado7  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 4º - Os atos de improbidade administrativa i...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 150. Sem prejuízo de outras garantias ass...
# 4     § 4º - Será declarada a perda da nacionalidade...
# ...                                                 ...
# 1263  § 5º Leis complementares da União e dos Estado...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 3º Constituem objetivos fundamentais da R...
# 1266  Art. 5º Todos são iguais perante a lei, sem di...
# 1267  Art. 144. A segurança pública, dever do Estado...
#
#                         endereço7  \
# 0        cf88,2,11,3,,41,444,117,
# 1           cf88,2,11,2,,37,393,,
# 2             cf88,1,3,,,14,172,,
# 3     cf88,5,19,36,,157,1004,335,
# 4             cf88,1,2,,,11,154,,
# ...                           ...
# 1263      cf88,3,15,28,,132,904,,
# 1264            cf88,1,0,,,4,26,,
# 1265              cf88,0,,,,2,9,,
# 1266            cf88,1,0,,,4,51,,
# 1267     cf88,4,18,,,149,981,322,
#
#                                              resultado8  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 170. A ordem econômica, fundada na valori...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 150. Sem prejuízo de outras garantias ass...
# 4     Art. 128. O Ministério Público abrange:§ 5º Le...
# ...                                                 ...
# 1263  § 2º Cabe aos Estados explorar diretamente, ou...
# 1264  Art. 8º É livre a associação profissional ou s...
# 1265  Art. 1º A República Federativa do Brasil, form...
# 1266  § 6º As pessoas jurídicas de direito público e...
# 1267  Art. 227. É dever da família, da sociedade e d...
#
#                          endereço8  \
# 0         cf88,2,11,3,,41,444,118,
# 1           cf88,6,21,,,187,1182,,
# 2                 cf88,1,3,,,14,,,
# 3      cf88,5,19,36,,157,1004,335,
# 4     cf88,3,15,28,,132,904,291,21
# ...                            ...
# 1263           cf88,2,7,,,24,294,,
# 1264               cf88,1,1,,,7,,,
# 1265               cf88,0,,,,0,4,,
# 1266         cf88,2,11,2,,37,395,,
# 1267     cf88,7,31,,,248,1475,535,
#
#                                              resultado9  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 4º - Os atos de improbidade administrativa i...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 148. A União, mediante lei complementar, ...
# 4     Art. 12. São brasileiros:II - naturalizados:b)...
# ...                                                 ...
# 1263  Art. 8º É livre a associação profissional ou s...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 170. A ordem econômica, fundada na valori...
# 1266  Art. 198. As ações e serviços públicos de saúd...
# 1267  Art. 5º Todos são iguais perante a lei, sem di...
#
#                      endereço9  \
# 0     cf88,2,11,3,,41,420,116,
# 1        cf88,2,11,2,,37,393,,
# 2          cf88,1,3,,,14,171,,
# 3      cf88,5,19,35,,154,992,,
# 4        cf88,1,2,,,11,150,30,
# ...                        ...
# 1263        cf88,1,1,,,7,138,,
# 1264         cf88,1,0,,,4,28,,
# 1265    cf88,6,21,,,187,1186,,
# 1266  cf88,7,26,44,,215,1279,,
# 1267         cf88,1,0,,,4,53,,
#
#                                             resultado10  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 207. As universidades gozam de autonomia ...
# 2     Parágrafo único. Nos casos previstos nos incis...
# 3     Art. 223. Compete ao Poder Executivo outorgar ...
# 4     Art. 151. É vedado à União:III - instituir ise...
# ...                                                 ...
# 1263  § 2º A lei regulará a organização e o funciona...
# 1264  Art. 8º É livre a associação profissional ou s...
# 1265  Art. 4º A República Federativa do Brasil rege-...
# 1266  Art. 5º Todos são iguais perante a lei, sem di...
# 1267  Art. 225. Todos têm direito ao meio ambiente e...
#
#                      endereço10
# 0      cf88,2,11,3,,41,444,123,
# 1          cf88,7,27,47,,224,,,
# 2         cf88,3,12,9,,53,516,,
# 3            cf88,7,29,,,244,,,
# 4      cf88,5,19,36,,158,1017,,
# ...                         ...
# 1263    cf88,3,13,19,3,91,691,,
# 1264         cf88,1,1,,,7,141,,
# 1265           cf88,0,,,,3,11,,
# 1266         cf88,1,0,,,4,54,3,
# 1267  cf88,7,30,,,246,1458,528,
#
# [1268 rows x 32 columns]

# %%
def clicar_botao_salvar (dataframe_questoes_sem_classificar, endereço_questão, dataframe_questões_classificadas):
    '1)vai inlcuir no dataframe_questões_classificadas a primeira linha do dataframe_questoes_sem_classificar e o endereço_questão'
    '2)vai deletar a primeira linha do dataframe_questoes_sem_classificar'
    '3) vai: salvar o dataframe_questoes_sem_classificar sem a primeira linha ; salvar o dataframe_questões_classificadas com a questão incluida'
    return ('dataframe_questoes_sem_classificar sem a primeira linha','dataframe_questões_classificadas com a questão adicionada' )

# %%
def clicar_botão_pular (dataframe_questoes_sem_classificar, dataframe_questões_puladas):
    '1) vai incluir no dataframe_questões_puladas a primeira linha do dataframe_questoes_sem_classificar'
    '2)vai deletar a primeira linha do dataframe_questoes_sem_classificar'
    '3) vai: salvar o dataframe_questoes_sem_classificar sem a primeira linha ; salvar o dataframe_questões_puladas com a questão incluida'
    return ('dataframe_questoes_sem_classificar sem a primeira linha','dataframe_questões_puladas com a questão adicionada' )

# %%
df_questoes_final.columns
# Out:
# Index(['IndQconc', 'Assuntos', 'Ano', '5', 'Orgao', 'Cargo', 'Questão', 'Tipo',
#        'gabarito', 'comando', 'texto item', 'referencia_comentario',
#        'resultado1', 'endereço1', 'resultado2', 'endereço2', 'resultado3',
#        'endereço3', 'resultado4', 'endereço4', 'resultado5', 'endereço5',
#        'resultado6', 'endereço6', 'resultado7', 'endereço7', 'resultado8',
#        'endereço8', 'resultado9', 'endereço9', 'resultado10', 'endereço10'],
#       dtype='object')

# %%
df_questoes_final
# Out:
#       IndQconc                                           Assuntos   Ano  \
# 0      1786102  Administração Pública – Disposições Gerais e S...  2021
# 1      1786101  Administração Pública – Disposições Gerais e S...  2021
# 2      1786100  Administração Pública – Disposições Gerais e S...  2021
# 3      1786099  Administração Pública – Disposições Gerais e S...  2021
# 4      1786098                          Direitos da Nacionalidade  2021
# ...        ...                                                ...   ...
# 1263    967373         Direitos Individuais , Direito à Liberdade  2019
# 1264    967372         Direitos Individuais , Direito à Liberdade  2019
# 1265    967371  Princípios Fundamentais da República , Objetiv...  2019
# 1266    967293  Administração Pública – Disposições Gerais e S...  2019
# 1267    965650  Defesa do Estado e das Instituições Democrátic...  2019
#
#             5              Orgao                             Cargo  \
# 0     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 1     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 2     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 3     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# 4     Quadrix  CREFONO-4ª Região              Fonoaudiólogo Fiscal
# ...       ...                ...                               ...
# 1263  Quadrix              CRESS                  SC Agente Fiscal
# 1264  Quadrix              CRESS                  SC Agente Fiscal
# 1265  Quadrix              CRESS                  SC Agente Fiscal
# 1266  Quadrix              CRESS  SC Assistente Administrativo Jr.
# 1267    CESPE                PRF       Policial Rodoviário Federal
#
#                                                 Questão          Tipo  \
# 0     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 1     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 2     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 3     O artigo 37 da Constituição Federal de 1988 di...  Certo/Errado
# 4     A expressão “direitos fundamentais” surgiu na ...  Certo/Errado
# ...                                                 ...           ...
# 1263  Em relação à Constituição Federal de 1988 (CF)...  Certo/Errado
# 1264  Em relação à Constituição Federal de 1988 (CF)...  Certo/Errado
# 1265  Em relação à Constituição Federal de 1988 (CF)...  Certo/Errado
# 1266  Quanto aos agentes e serviços públicos, julgue...  Certo/Errado
# 1267  À luz da Constituição Federal de 1988, julgue ...  Certo/Errado
#
#      gabarito                                            comando  ...  \
# 0       Certo  O artigo 37 da Constituição Federal de 1988 di...  ...
# 1      Errado  O artigo 37 da Constituição Federal de 1988 di...  ...
# 2       Certo  O artigo 37 da Constituição Federal de 1988 di...  ...
# 3       Certo  O artigo 37 da Constituição Federal de 1988 di...  ...
# 4      Errado  A expressão “direitos fundamentais” surgiu na ...  ...
# ...       ...                                                ...  ...
# 1263    Certo  Em relação à Constituição Federal de 1988 (CF)...  ...
# 1264   Errado  Em relação à Constituição Federal de 1988 (CF)...  ...
# 1265   Errado  Em relação à Constituição Federal de 1988 (CF)...  ...
# 1266   Errado  Quanto aos agentes e serviços públicos, julgue...  ...
# 1267    Certo  À luz da Constituição Federal de 1988, julgue ...  ...
#
#                                              resultado6  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 1º São princípios institucionais do Ministér...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     § 3º Em caso de greve em atividade essencial, ...
# 4     Art. 109. Aos juízes federais compete processa...
# ...                                                 ...
# 1263  § 1º São princípios institucionais do Ministér...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 1º A República Federativa do Brasil, form...
# 1266  § 2º A lei não poderá estabelecer distinção en...
# 1267  § 6º As pessoas jurídicas de direito público e...
#
#                      endereço6  \
# 0     cf88,2,11,3,,41,444,120,
# 1      cf88,3,15,28,,131,892,,
# 2          cf88,1,3,,,14,173,,
# 3      cf88,3,14,24,,118,861,,
# 4      cf88,3,14,23,,112,833,,
# ...                        ...
# 1263   cf88,3,15,28,,131,892,,
# 1264         cf88,1,0,,,4,34,,
# 1265           cf88,0,,,,0,3,,
# 1266       cf88,1,2,,,11,152,,
# 1267     cf88,2,11,2,,37,395,,
#
#                                              resultado7  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 4º - Os atos de improbidade administrativa i...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 150. Sem prejuízo de outras garantias ass...
# 4     § 4º - Será declarada a perda da nacionalidade...
# ...                                                 ...
# 1263  § 5º Leis complementares da União e dos Estado...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 3º Constituem objetivos fundamentais da R...
# 1266  Art. 5º Todos são iguais perante a lei, sem di...
# 1267  Art. 144. A segurança pública, dever do Estado...
#
#                         endereço7  \
# 0        cf88,2,11,3,,41,444,117,
# 1           cf88,2,11,2,,37,393,,
# 2             cf88,1,3,,,14,172,,
# 3     cf88,5,19,36,,157,1004,335,
# 4             cf88,1,2,,,11,154,,
# ...                           ...
# 1263      cf88,3,15,28,,132,904,,
# 1264            cf88,1,0,,,4,26,,
# 1265              cf88,0,,,,2,9,,
# 1266            cf88,1,0,,,4,51,,
# 1267     cf88,4,18,,,149,981,322,
#
#                                              resultado8  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 170. A ordem econômica, fundada na valori...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 150. Sem prejuízo de outras garantias ass...
# 4     Art. 128. O Ministério Público abrange:§ 5º Le...
# ...                                                 ...
# 1263  § 2º Cabe aos Estados explorar diretamente, ou...
# 1264  Art. 8º É livre a associação profissional ou s...
# 1265  Art. 1º A República Federativa do Brasil, form...
# 1266  § 6º As pessoas jurídicas de direito público e...
# 1267  Art. 227. É dever da família, da sociedade e d...
#
#                          endereço8  \
# 0         cf88,2,11,3,,41,444,118,
# 1           cf88,6,21,,,187,1182,,
# 2                 cf88,1,3,,,14,,,
# 3      cf88,5,19,36,,157,1004,335,
# 4     cf88,3,15,28,,132,904,291,21
# ...                            ...
# 1263           cf88,2,7,,,24,294,,
# 1264               cf88,1,1,,,7,,,
# 1265               cf88,0,,,,0,4,,
# 1266         cf88,2,11,2,,37,395,,
# 1267     cf88,7,31,,,248,1475,535,
#
#                                              resultado9  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     § 4º - Os atos de improbidade administrativa i...
# 2     Art. 15. É vedada a cassação de direitos polít...
# 3     Art. 148. A União, mediante lei complementar, ...
# 4     Art. 12. São brasileiros:II - naturalizados:b)...
# ...                                                 ...
# 1263  Art. 8º É livre a associação profissional ou s...
# 1264  Art. 5º Todos são iguais perante a lei, sem di...
# 1265  Art. 170. A ordem econômica, fundada na valori...
# 1266  Art. 198. As ações e serviços públicos de saúd...
# 1267  Art. 5º Todos são iguais perante a lei, sem di...
#
#                      endereço9  \
# 0     cf88,2,11,3,,41,420,116,
# 1        cf88,2,11,2,,37,393,,
# 2          cf88,1,3,,,14,171,,
# 3      cf88,5,19,35,,154,992,,
# 4        cf88,1,2,,,11,150,30,
# ...                        ...
# 1263        cf88,1,1,,,7,138,,
# 1264         cf88,1,0,,,4,28,,
# 1265    cf88,6,21,,,187,1186,,
# 1266  cf88,7,26,44,,215,1279,,
# 1267         cf88,1,0,,,4,53,,
#
#                                             resultado10  \
# 0     Art. 40. O regime próprio de previdência socia...
# 1     Art. 207. As universidades gozam de autonomia ...
# 2     Parágrafo único. Nos casos previstos nos incis...
# 3     Art. 223. Compete ao Poder Executivo outorgar ...
# 4     Art. 151. É vedado à União:III - instituir ise...
# ...                                                 ...
# 1263  § 2º A lei regulará a organização e o funciona...
# 1264  Art. 8º É livre a associação profissional ou s...
# 1265  Art. 4º A República Federativa do Brasil rege-...
# 1266  Art. 5º Todos são iguais perante a lei, sem di...
# 1267  Art. 225. Todos têm direito ao meio ambiente e...
#
#                      endereço10
# 0      cf88,2,11,3,,41,444,123,
# 1          cf88,7,27,47,,224,,,
# 2         cf88,3,12,9,,53,516,,
# 3            cf88,7,29,,,244,,,
# 4      cf88,5,19,36,,158,1017,,
# ...                         ...
# 1263    cf88,3,13,19,3,91,691,,
# 1264         cf88,1,1,,,7,141,,
# 1265           cf88,0,,,,3,11,,
# 1266         cf88,1,0,,,4,54,3,
# 1267  cf88,7,30,,,246,1458,528,
#
# [1268 rows x 32 columns]

# %%
df_questoes_final.to_csv ('falta_catalogar_final.csv',index= False)

# %%
endresultado = os.getcwd() + '\\resultado\\'
if not os.path.exists(endresultado):
    os.makedirs ('resultado')


if os.path.isfile(endresultado+'resultado.csv'):
    df_resultado = pd.read_csv (endresultado+'resultado.csv')
    print ('df_resultado foi carregado do arquivo já salvo')
else:
    df_resultado = pd.DataFrame (columns=['IndQconc', 'Assuntos', 'Ano', '5', 'Orgao', 'Cargo', 'Questão', 'Tipo','gabarito', 'comando', 'texto item'])
    df_resultado.to_csv (endresultado+'resultado.csv', index=False)
    print ('criado o df_resultado')


if os.path.isfile(endresultado+'falta_catalogar.csv'):
    df_falta_catalogar = pd.read_csv (endresultado+'falta_catalogar.csv')
    print ('df_falta_catalogar foi carregado do arquivo já salvo')
else:
    df_falta_catalogar =pd.read_csv (os.getcwd() + '\\'+'falta_catalogar_final.csv')
    df_falta_catalogar.to_csv (endresultado+'falta_catalogar.csv',index=False)
    print ('criado o df_falta_catalogar')

if os.path.isfile(endresultado+'verificar_depois.csv'):
    df_verificar_depois = pd.read_csv (endresultado+'verificar_depois.csv')
    print ('df_verificar_depois foi carregado do arquivo já salvo')
else:
    df_verificar_depois = pd.DataFrame (columns=[df_questoes_final.columns])
    df_verificar_depois.to_csv (endresultado+'verificar_depois.csv', index=False)
    print ('criado o df_verificar_depois')
# Out:
# df_resultado foi carregado do arquivo já salvo
# df_falta_catalogar foi carregado do arquivo já salvo
# df_verificar_depois foi carregado do arquivo já salvo

# %%
df_lei = pd.read_csv ('CFcsvtudolei.csv')

# %%
df_lei
# Out:
#       Unnamed: 0                                           original  \
# 0              0  Art. 1º A República Federativa do Brasil, form...
# 1              6                                   I - a soberania;
# 2              7                                   II - a cidadania
# 3              8                III - a dignidade da pessoa humana;
# 4             10  IV - os valores sociais do trabalho e da livre...
# ...          ...                                                ...
# 2397        3322  Art. 247. As leis previstas no inciso III do §...
# 2398        3323  Parágrafo único. Na hipótese de insuficiência ...
# 2399        3324  Art. 248. Os benefícios pagos, a qualquer títu...
# 2400        3325  Art. 249. Com o objetivo de assegurar recursos...
# 2401        3326  Art. 250. Com o objetivo de assegurar recursos...
#
#                                                   Texto              endereço  \
# 0     Art. 1º A República Federativa do Brasil, form...        cf88,0,,,,0,,,
# 1     Art. 1º A República Federativa do Brasil, form...       cf88,0,,,,0,0,,
# 2     Art. 1º A República Federativa do Brasil, form...       cf88,0,,,,0,1,,
# 3     Art. 1º A República Federativa do Brasil, form...       cf88,0,,,,0,2,,
# 4     Art. 1º A República Federativa do Brasil, form...       cf88,0,,,,0,3,,
# ...                                                 ...                   ...
# 2397  Art. 247. As leis previstas no inciso III do §...      cf88,8,,,,268,,,
# 2398  Parágrafo único. Na hipótese de insuficiência ...  cf88,8,,,,268,1511,,
# 2399  Art. 248. Os benefícios pagos, a qualquer títu...      cf88,8,,,,269,,,
# 2400  Art. 249. Com o objetivo de assegurar recursos...      cf88,8,,,,270,,,
# 2401  Art. 250. Com o objetivo de assegurar recursos...      cf88,8,,,,271,,,
#
#             tipo
# 0            art
# 1     art-inciso
# 2     art-inciso
# 3     art-inciso
# 4     art-inciso
# ...          ...
# 2397         art
# 2398         par
# 2399         art
# 2400         art
# 2401         art
#
# [2402 rows x 5 columns]

# %%
valor = 'cf88,0,,,,0,,,'

# %%
def procura_texto (df_lei,endereço):
    resultado = df_lei.Texto.where(df_lei.endereço == endereço)
    resultado = resultado.dropna()
    resultado = resultado.values
    return (resultado[0])

# %%
df_falta_catalogar.head(1)
# Out:
#    IndQconc                   Assuntos   Ano        5              Orgao  \
# 0   1786098  Direitos da Nacionalidade  2021  Quadrix  CREFONO-4ª Região
#
#                   Cargo                                            Questão  \
# 0  Fonoaudiólogo Fiscal  A expressão “direitos fundamentais” surgiu na ...
#
#            Tipo gabarito                                            comando  \
# 0  Certo/Errado   Errado  A expressão “direitos fundamentais” surgiu na ...
#
#    ...                                         resultado6  \
# 0  ...  Art. 109. Aos juízes federais compete processa...
#
#                  endereço6                                         resultado7  \
# 0  cf88,3,14,23,,112,833,,  § 4º - Será declarada a perda da nacionalidade...
#
#              endereço7                                         resultado8  \
# 0  cf88,1,2,,,11,154,,  Art. 128. O Ministério Público abrange:§ 5º Le...
#
#                       endereço8  \
# 0  cf88,3,15,28,,132,904,291,21
#
#                                           resultado9              endereço9  \
# 0  Art. 12. São brasileiros:II - naturalizados:b)...  cf88,1,2,,,11,150,30,
#
#                                          resultado10                endereço10
# 0  Art. 151. É vedado à União:III - instituir ise...  cf88,5,19,36,,158,1017,,
#
# [1 rows x 32 columns]

# %%
df_falta_catalogar.columns
# Out:
# Index(['IndQconc', 'Assuntos', 'Ano', '5', 'Orgao', 'Cargo', 'Questão', 'Tipo',
#        'gabarito', 'comando', 'texto item', 'referencia_comentario',
#        'resultado1', 'endereço1', 'resultado2', 'endereço2', 'resultado3',
#        'endereço3', 'resultado4', 'endereço4', 'resultado5', 'endereço5',
#        'resultado6', 'endereço6', 'resultado7', 'endereço7', 'resultado8',
#        'endereço8', 'resultado9', 'endereço9', 'resultado10', 'endereço10'],
#       dtype='object')

# %%
def botoes_comentario (linha_questao,df_lei):
    listabotoes_coment =[]
    aux_listacoment = eval(linha_questao.referencia_comentario.values[0])
    if aux_listacoment:
        for item in aux_listacoment:
            listabotoes_coment.append([item,procura_texto(df_lei,item)])
    return (listabotoes_coment)

# %%
def botoes_top10 (linha_questao):
    listabotoes_top10 =[]
    for i in range (1,11):
        listabotoes_top10.append ([linha_questao['endereço'+str(i)][0],linha_questao['resultado'+str(i)][0]])
    return (listabotoes_top10)

# %%
def pega_linha1 (df_falta_catalogar):
    primeiralinha = df_falta_catalogar.head(1)
    texto_item =primeiralinha['texto item'][0]
    bot_comentario = botoes_comentario (primeiralinha,df_lei)
    bot_top10 = botoes_top10 (primeiralinha)
    return (texto_item,bot_comentario,bot_top10)

# %%
texto_item, bot_comentario,bot_top10 = pega_linha1 (df_falta_catalogar)

# %%
print (texto_item)
print ('-'*30)
print (bot_comentario)
print ('-'*30)
print (bot_top10)
print ('-'*30)
print (bot_top10[1])
# Out:
#  A Constituição Federal de 1988 contemplou a naturalização tácita, ou grande naturalização, na qual um cônjuge adquire automaticamente a nacionalidade do outro em razão do casamento.
# ------------------------------
# []
# ------------------------------
# [['cf88,1,2,,,11,154,39,0', 'Art. 12. São brasileiros:§ 4º - Será declarada a perda da nacionalidade do brasileiro que:II - adquirir outra nacionalidade, salvo nos casos:\xa0(Redação dada pela Emenda Constitucional de Revisão nº 3, de 1994)a) de reconhecimento de nacionalidade originária pela lei estrangeira;\xa0(Incluído pela Emenda Constitucional de Revisão nº 3, de 1994)'], ['cf88,1,2,,,11,154,39,1', 'Art. 12. São brasileiros:§ 4º - Será declarada a perda da nacionalidade do brasileiro que:II - adquirir outra nacionalidade, salvo nos casos:\xa0(Redação dada pela Emenda Constitucional de Revisão nº 3, de 1994)b) de imposição de naturalização, pela norma estrangeira, ao brasileiro residente em estado estrangeiro, como condição para permanência em seu território ou para o exercício de direitos civis;\xa0(Incluído pela Emenda Constitucional de Revisão nº 3, de 1994)'], ['cf88,1,2,,,11,154,38,', 'Art. 12. São brasileiros:§ 4º - Será declarada a perda da nacionalidade do brasileiro que:I - tiver cancelada sua naturalização, por sentença judicial, em virtude de atividade nociva ao interesse nacional;'], ['cf88,1,2,,,11,154,39,', 'Art. 12. São brasileiros:§ 4º - Será declarada a perda da nacionalidade do brasileiro que:II - adquirir outra nacionalidade, salvo nos casos:\xa0(Redação dada pela Emenda Constitucional de Revisão nº 3, de 1994)'], ['cf88,1,3,,,14,171,,', 'Art. 15. É vedada a cassação de direitos políticos, cuja perda ou suspensão só se dará nos casos de:I - cancelamento da naturalização por sentença transitada em julgado;'], ['cf88,3,14,23,,112,833,,', 'Art. 109. Aos juízes federais compete processar e julgar:X - os crimes de ingresso ou permanência irregular de estrangeiro, a execução de carta rogatória, após o "exequatur", e de sentença estrangeira, após a homologação, as causas referentes à nacionalidade, inclusive a respectiva opção, e à naturalização;'], ['cf88,1,2,,,11,154,,', '§ 4º - Será declarada a perda da nacionalidade do brasileiro que:'], ['cf88,3,15,28,,132,904,291,21', 'Art. 128. O Ministério Público abrange:§ 5º Leis complementares da União e dos Estados, cuja iniciativa é facultada aos respectivos Procuradores-Gerais, estabelecerão a organização, as atribuições e o estatuto de cada Ministério Público, observadas, relativamente a seus membros:I - as seguintes garantias:a) vitaliciedade, após dois anos de exercício, não podendo perder o cargo senão por sentença judicial transitada em julgado;------> OBS.: A condenação criminal, com trânsito em julgado, por crime incompatível com o exercício do cargo, NÃO pode acarretar, como efeito da condenação, a perda do cargo de membro vitalício do Ministério Público, A PERDA DO CARGO SÓ PODE OCORRE POR SENTENÇA JUDICIAL TRANSITADA EM JULGADO PROFERIDA EM AÇÃO CIVIL PRÓPRIA.'], ['cf88,1,2,,,11,150,30,', 'Art. 12. São brasileiros:II - naturalizados:b) os estrangeiros de qualquer nacionalidade, residentes na República Federativa do Brasil há mais de quinze anos ininterruptos e sem condenação penal, desde que requeiram a nacionalidade brasileira.\xa0(Redação dada pela Emenda Constitucional de Revisão nº 3, de 1994)'], ['cf88,5,19,36,,158,1017,,', 'Art. 151. É vedado à União:III - instituir isenções de tributos da competência dos Estados, do Distrito Federal ou dos Municípios.------> OBS.: é vedado à União dispor sobre a isenção de impostos de competência estadual, SALVO SE TAL ISENÇÃO OCORRER em decorrência de sua atuação no âmbito internacional. Ocorre que a vedação contempla apenas o ente federativo União, pessoa jurídica de direito interno, não se referindo ao Estado Brasileiro, pessoa jurídica de direito externo. Conforme entendimento do STF, pode o Estado Brasileiro conceder isenções heterônomas nessa qualidade: ?A cláusula de vedação inscrita no art. 151, inciso III, da Constituição ? que proíbe a concessão de isenções tributárias heterônomas ? é imponível ao Estado Federal brasileiro (vale dizer, à República Federativa do Brasil), incidindo, unicamente, no plano da ...
# ------------------------------
# ['cf88,1,2,,,11,154,39,1', 'Art. 12. São brasileiros:§ 4º - Será declarada a perda da nacionalidade do brasileiro que:II - adquirir outra nacionalidade, salvo nos casos:\xa0(Redação dada pela Emenda Constitucional de Revisão nº 3, de 1994)b) de imposição de naturalização, pela norma estrangeira, ao brasileiro residente em estado estrangeiro, como condição para permanência em seu território ou para o exercício de direitos civis;\xa0(Incluído pela Emenda Constitucional de Revisão nº 3, de 1994)']

# %%
def botao_passar (df_falta_catalogar,df_verificar_depois,end_pasta_versao):
    df_falta_catalogar.head(1)
    df_verificar_depois= df_verificar_depois.append(df_falta_catalogar.head(1))
    df_falta_catalogar.drop(df_falta_catalogar.head(1).index,axis=0,inplace= True)
    df_verificar_depois.to_csv(end_pasta_versao+'verificar_depois.csv',index=False)
    df_falta_catalogar.to_csv(end_pasta_versao+'falta_catalogar.csv',index=False)
    return (df_verificar_depois)

# %%
df_verificar_depois = botao_passar (df_falta_catalogar,df_verificar_depois,endresultado)

# %% [markdown]
# Botão Pesquisar

# %%
dfart = pd.read_csv (r'CFcsvart.csv')
dfniv2 = pd.read_csv (r'CFcsvniv2.csv')
dfniv3 = pd.read_csv (r'CFcsvniv3.csv')
dfniv4 = pd.read_csv (r'CFcsvniv4.csv')
df_solei  = pd.read_csv(r'CFcsvtudolei.csv')

# %%
artigo = re.compile (r"[a,A]rt.?\s?([0-9]{1,3})\s?-?[A-Z]?", flags= re.IGNORECASE)
artigopesq = re.compile (r'\bart\.?(?:igo)?\b.*?([0-9]{1,3})',flags= re.IGNORECASE)
paragrafo1 = re.compile (r'§\s*([0-9][0-9]?|.nico)',flags= re.IGNORECASE)
paragrafo2 = re.compile (r'p[a.]?(?:r.grafo)?\s*([0-9][0-9]?)',flags= re.IGNORECASE)
punico = re.compile (r'\bp.?(?:r.grafo)?\s*[u,ú](?:nico)?\b',flags= re.IGNORECASE)
inciso = re.compile (r"\s?([LVIX]{1,7})")
alinea1 = re.compile (r'al.nea.*?\b([a-z])\b',flags= re.IGNORECASE)
alinea2 = re.compile (r"['\"]([a-z])['\"]")

# %%
def porvalor (valor,df_tratado_por_indice): #no caso de artigo usar o df com todos os artigos
        valor = str(valor)
        resultado = df_tratado_por_indice.index.where(df_tratado_por_indice.end == valor)
        resultado = resultado.dropna()
        try:
                indice = resultado[0] #
                return (int(indice))
        except:
                return("")
                
def verificaproximodf (indice,df_baixo):
    colunas = df_baixo.columns
    colunasdesejadas = 'art','niv2','niv3','niv4'
    for coluna in colunas:
        if coluna not in colunasdesejadas:
            df_baixo= df_baixo.drop ([coluna],axis=1)
    colunaanterior = df_baixo.iloc[:,-1].name
    df_resultado = df_baixo[colunaanterior].where(df_baixo[colunaanterior] == indice)
    df_resultado = df_resultado.dropna()
    df_resultado
    return (df_resultado.size > 0)

def niv2porindice (indiceart,dfniv2): 
    indiceart = int(indiceart)
    resultado = pd.DataFrame (columns=['Texto'])
    resultado['Texto'] = dfniv2['Texto'].where(dfniv2.art==indiceart)
    resultado['end'] = dfniv2['end'].where(dfniv2.art==indiceart)
    resultado['endereço'] = dfniv2['endereço'].where(dfniv2.art==indiceart)
    resultado = resultado.dropna()
    if resultado.size == 0:
        resultado = ""
    return (resultado)
def niv3porindice (indiceart,dfniv3):
    indiceart = int(indiceart)
    resultado = pd.DataFrame (columns=['Texto'])
    resultado['Texto'] = dfniv3['Texto'].where(dfniv3.niv2==indiceart)
    resultado['end'] = dfniv3['end'].where(dfniv3.niv2==indiceart)
    resultado['endereço'] = dfniv3['endereço'].where(dfniv3.niv2==indiceart)
    resultado = resultado.dropna()
    if resultado.size == 0:
        resultado = ""
    return (resultado)
def niv4porindice (indiceart,dfniv4):
    indiceart = int(indiceart)
    resultado = pd.DataFrame (columns=['Texto'])
    resultado['Texto'] = dfniv4['Texto'].where(dfniv4.niv3==indiceart)
    resultado['end'] = dfniv4['end'].where(dfniv4.niv3==indiceart)
    resultado['endereço'] = dfniv4['endereço'].where(dfniv4.niv3==indiceart)
    resultado = resultado.dropna()
    if resultado.size == 0:
        resultado = ""
    return (resultado)
def achaart (texto):
    trecholei = artigo.search(texto)
    if trecholei is None:
        resultado =""
    else:
        resultado = trecholei.group(1)
    return resultado
def paragrafocoment (texto):
    resultado = ""
    aux = paragrafo1.search (texto)
    if aux is not None:
        try:
            int (aux.group(1))
            resultado = aux.group(1)
        except:
            resultado = 'Parágrafo Único'
    aux = paragrafo2.search (texto)
    if aux is not None:
        resultado = aux.group(1)
    aux = punico.search (texto)
    if aux is not None:
        resultado = 'Parágrafo Único'
    return (resultado)
def artcoment (texto):
    resultado = artigopesq.search (texto)
    if resultado is not None:
        resultado = resultado.group(1)
    else:
        resultado =""
    return (resultado)
def incicoment (texto):
    resultado = inciso.search (texto)
    if resultado is not None:
        resultado = resultado.group(1)
    else:
        resultado =""
    return (resultado)
def achaalinea (texto):
    aux1 =  alinea1.search(texto)
    aux2 = alinea2.search (texto)
    resultado = ""
    if aux1 is not None:
        resultado = aux1.group(1)
    elif aux2 is not None:
        resultado = aux2.group(1)
    return (resultado)
def procuradf (textoprocurado, coluna):
    resultado =  coluna.where(coluna == textoprocurado).dropna()
    return (not resultado.empty)

# %%
def procurar (texto,dfart,dfniv2,dfniv3,dfniv4):
    resultado=""
    auxart = artcoment(texto)
    if auxart != "" and int(auxart) in dfart.index.values:
            indartigo = porvalor (auxart,dfart) #acha o indice do artigo
            if verificaproximodf (indartigo,dfniv2): #verifica se tem o nivel 2
                auxniv2=""
                df_pesq_niv2 = niv2porindice (indartigo,dfniv2) #retorna o nivel 2 do artigo achado
                auxparagrafo = paragrafocoment (texto)
                auxniv2 = auxparagrafo
                if auxparagrafo != "":
                    tiponiv2 = "paragrafo"
                if not procuradf (auxparagrafo, df_pesq_niv2['end']):
                    auxparagrafo = ""
                    auxniv2 = auxparagrafo
                    tiponiv2 =""
                if auxparagrafo == "":
                    auxinciso = incicoment (texto)
                    auxniv2 = auxinciso
                    tiponiv2 = 'inciso'
                    if not procuradf (auxinciso, df_pesq_niv2['end']):
                        auxinciso = ""
                        auxniv2 = auxinciso
                        tiponiv2 =""
                if auxniv2 =="":
                    resultado = dfart.endereço[indartigo]
                else:
                    indniv2 = porvalor (auxniv2,df_pesq_niv2)
                    df_pesq_niv3 = niv3porindice (indniv2, dfniv3)
                    if verificaproximodf (indniv2,dfniv3):
                        if tiponiv2 == 'paragrafo':
                            auxinciso = incicoment (texto)
                            if  not  procuradf (auxinciso, df_pesq_niv3['end']):
                                auxinciso =""
                            if auxinciso =="":
                                resultado = dfniv2.endereço[indniv2]
                            else:
                                indniv3 = porvalor (auxinciso,df_pesq_niv3)
                                if verificaproximodf (indniv3,dfniv4):
                                    df_pesq_niv4 = niv4porindice (indniv3,dfniv4)
                                    auxalinea = achaalinea (texto)
                                    if not procuradf (auxalinea, df_pesq_niv4['end']):
                                        auxalinea = ""
                                    if auxalinea == "":
                                        resultado= dfniv3.endereço[indniv3]
                                    else:
                                        indniv4 = porvalor (auxalinea, df_pesq_niv4)
                                        resultado = dfniv4.endereço[indniv4]
                                else:
                                    resultado = dfniv3.endereço[indniv3]
                        else:
                            df_pesq_niv3 = niv3porindice (indniv2, dfniv3)
                            auxalinea = achaalinea (texto)
                            if not procuradf (auxalinea, df_pesq_niv3['end']):
                                auxalinea = ""
                            if auxalinea == "":
                                resultado= dfniv2.endereço[indniv2]
                            else:
                                indniv3 = porvalor (auxalinea, df_pesq_niv3)
                                resultado = dfniv3.endereço[indniv3]

                    else:
                        resultado = dfniv2.endereço[indniv2]       
            else:
                if indartigo !="":
                    resultado = dfart.endereço[indartigo]
    else:
        resultado =  ("")
    return (resultado)
